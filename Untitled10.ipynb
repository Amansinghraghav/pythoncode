# %%
from getpass import getpass
bank = {'user' : ['aman','ashu','singh','raghav'],
        'acc'  : [1001,1002,1003,1004],
        'password' :['amanashu','ashuaman','singh109','raghav109'] ,
        'bal'   :[1000000000,1000000000,100000000,100000000]
        }
admin ='bhai'
admin_password ='raghav007'
while True :
    def debit() :
        debit_ammount=float(input('enter the ammount debit in your account : '))
        bank['bal'][index1]= bank['bal'][index1] +debit_ammount
        print('sucessfully debit ammount')
    def credit() :
        credit_ammount=float(input('enter the ammount credit in your account : '))
        if credit_ammount <=  bank['bal'][index1] :
            bank['bal'][index1] = bank['bal'][index1] - credit_ammount
            print('sucessfully credit ammount ')
        else :
            print('insufficent balance in your account')
    def balance() :
         total_balance =bank['bal'][index1]
         print('your total balance = {}'.format(total_balance))
    def password() :
        new_password = getpass('enter the new password ')
        bank['password'][index1] = new_password
        print('sucessfully change password ')
    def signup() :
         acc =bank['acc'][-1] + 1
        user_name = input('enter your name : ')
        user_password = getpass('enter the password : ')
        balance=float(input('enter ammount : '))
        bank['user'].append(user_name)
        bank['password'].append(user_password)
        bank['acc'].append(acc)
        bank['bal'].append(balance)
        print('sucessfully created your account ')
        print('note down your account number = {}'.format(acc))
        print('now you can login account : {}'.format(user_name))
    print('*'*50)
    print('          Wellcome to Python Bank')
    print('*'*50)
    print('\n\n1. login \n2. singup \n3. admin \n4. exit\n\n')
    choise=int(input('enter your choise : '))
    if(choise == 4) :
        exit_choise = input('Are you sure exit the bank yes/no : ').strip().lower()
        if exit_choise == 'yes' or exit_choise == 'y' :
            print('thanx for using servise')
            break
    elif(choise == 3) :
        admin1 = input('enter the admin name : ').strip().lower()
        admin_password1 = getpass('enter the password ')
        if admin == admin1 :
            if admin_password1 == admin_password :
                print()
                for key,value in bank.items() :
                    print('{} = {}'.format(key,value))
            else :
                print('\n password is wrong ')
        else :
            print('\nyou are not the admin ')
    elif(choise == 2) :
        signup()
    elif(choise == 1) :
        uacc = int(input('enter your account number : '))
        if uacc in bank['acc'] :
            password1 = getpass('enter your password : ')
            index1 = bank['acc'].index(uacc)
            if password1 != bank['password'].index(password1) :
                print('sucessfully login account {}'.format(bank['user'][index1]))
                print('\n')
                while True :
                    print("\n\n1. Debit\n2. Credit\n3. Check Balance\n4. Change Password \n5. Logout")
                    bank['bal'][index1]
                    ch = int(input("Choice : "))
                    if ch == 1 :
                        debit()
                    elif ch == 2 :
                        credit()
                    elif ch == 3 :
                        balance()
                    elif ch == 4 : 
                        password()
                    elif ch == 5 :
                        print("\nLogging you out.....\n")
                        break
                    else :
                        print("\n\nInvalid Choice ")
                        print("Try Again")
                else :
                    print("\n\nInvalid Password\n\nTry Again")
            else :
                print('wrong password')
        else :                   
            print('wrong accoun number ')
                                                            
    break
# Out:
# **************************************************
#           Wellcome to Python Bank
# **************************************************
#
#
# 1. login
# 2. singup
# 3. admin
# 4. exit
#
#
# enter your choise : 1
# enter your account number : 1001
# enter your password : ········
# sucessfully login account aman
#
#
#
#
# 1. Debit
# 2. Credit
# 3. Check Balance
# 4. Change Password
# 5. Logout
# Choice : 3
# your total balance = 1000000000
#
#
# 1. Debit
# 2. Credit
# 3. Check Balance
# 4. Change Password
# 5. Logout

# %%
l=[]
for i in range (1000,2020) :
    if i%4==0 :
       l.append(i)
    else :
        continue
